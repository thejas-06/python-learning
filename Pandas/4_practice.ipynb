# %%
#what is the total sales of audi
import pandas as pd
a=pd.read_csv("data/car_done.csv")
a.head()
# Out:
#    Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0           0        Acura  Integra              16.919
# 1           1        Acura       TL              39.384
# 2           2        Acura       CL              14.114
# 3           3        Acura       RL               8.588
# 4           4         Audi       A4              20.397
#
#    four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                  16.360    Passenger               21.50          1.8
# 1                  19.875    Passenger               28.40          3.2
# 2                  18.225    Passenger                 NaN          3.2
# 3                  29.725    Passenger               42.00          3.5
# 4                  22.255    Passenger               23.99          1.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              157 non-null    int64
#  1   Manufacturer            157 non-null    object
#  2   Model                   157 non-null    object
#  3   Sales_in_thousands      157 non-null    float64
#  4   four_year_resale_value  121 non-null    float64
#  5   Vehicle_type            157 non-null    object
#  6   Price_in_thousands      155 non-null    float64
#  7   Engine_size             156 non-null    float64
#  8   Horsepower              156 non-null    float64
#  9   Wheelbase               156 non-null    float64
#  10  Width                   156 non-null    float64
#  11  Length                  156 non-null    float64
#  12  Curb_weight             155 non-null    float64
#  13  Fuel_capacity           156 non-null    float64
# ...

# %%
a.dropna(inplace=True)
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 0 to 149
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              117 non-null    int64
#  1   Manufacturer            117 non-null    object
#  2   Model                   117 non-null    object
#  3   Sales_in_thousands      117 non-null    float64
#  4   four_year_resale_value  117 non-null    float64
#  5   Vehicle_type            117 non-null    object
#  6   Price_in_thousands      117 non-null    float64
#  7   Engine_size             117 non-null    float64
#  8   Horsepower              117 non-null    float64
#  9   Wheelbase               117 non-null    float64
#  10  Width                   117 non-null    float64
#  11  Length                  117 non-null    float64
#  12  Curb_weight             117 non-null    float64
#  13  Fuel_capacity           117 non-null    float64
# ...

# %%
b=a[a["Manufacturer"]=="Audi"]
b["Sales_in_thousands"].sum()
# Out:
# np.float64(40.557)

# %%
#what is the minimum sales of Volkswagen
c=a[a["Manufacturer"]=="Volkswagen"]
c["Sales_in_thousands"].min()
# Out:
# np.float64(5.596)

# %%
#what is the difference between count of car and passenger
d=a[a["Vehicle_type"]=="Car"]
e = a[a["Vehicle_type"]=="Passenger"]
f = len(d)-len(e)

# %%
abs(f)
# Out:
# 59

# %%
#return rows where sales is more then 100 and fuel capacity is more then 12
a[(a["Sales_in_thousands"]>100)& (a["Fuel_capacity"]>12)]
# Out:
#      Unnamed: 0 Manufacturer           Model  Sales_in_thousands  \
# 19           19    Chevrolet        Cavalier             145.519
# 20           20    Chevrolet          Malibu             135.126
# 40           40        Dodge      Ram Pickup             227.061
# 43           43        Dodge          Dakota             111.313
# 45           45        Dodge         Caravan             181.749
# 47           47         Ford         Mustang             113.369
# 49           49         Ford          Taurus             245.815
# 52           52         Ford        Explorer             276.747
# 53           53         Ford        Windstar             155.787
# 54           54         Ford      Expedition             125.338
# 55           55         Ford          Ranger             220.650
# 56           56         Ford        F-Series             540.561
# 58           58        Honda          Accord             230.902
# ...

# %%
#return those rows where sales is more then average sales
a["Sales_in_thousands"].mean()
# Out:
# np.float64(59.112316239316236)

# %%
z=a[a["Sales_in_thousands"]>a["Sales_in_thousands"].mean()]

# %%
len(z)
# Out:
# 39

# %%
d["Manufacturer"].value_counts()
# Out:
# Manufacturer
# Dodge         5
# Ford          5
# Toyota        4
# Honda         3
# Jeep          3
# Mitsubishi    2
# Mercury       2
# Nissan        2
# Oldsmobile    2
# Plymouth      1
# Name: count, dtype: int64

# %%
s=a[a["Vehicle_type"]=="Car"]
am=s["Sales_in_thousands"].sum()
am
# Out:
# np.float64(2766.779000000001)

# %%
s=a[a["Vehicle_type"]=="Passenger"]
amo=s["Sales_in_thousands"].sum()
amo
# Out:
# np.float64(4149.362)

# %%
a.groupby(["Manufacturer"])["Sales_in_thousands"].sum().sort_values()
# Out:
# Manufacturer
# Porsche         12.128
# Infiniti        23.713
# BMW             26.758
# Audi            40.557
# Lexus           43.145
# Oldsmobile      60.180
# Plymouth        62.129
# Lincoln         62.709
# Acura           64.891
# Mercedes-B      66.079
# Cadillac        81.450
# Saturn         110.389
# Chrysler       117.545
# Hyundai        137.326
# Volkswagen     159.749
# Mitsubishi     180.895
# Mercury        237.999
# Buick          242.019
# Nissan         280.472
# Jeep           293.153
# Pontiac        330.962
# Chevrolet      446.370
# Honda          592.674
# Toyota         675.086
# Dodge          720.798
# Ford          1846.965
# Name: Sales_in_thousands, dtype: float64

# %%
a.groupby(["Manufacturer"])["Sales_in_thousands"].sum().sort_values()
# Out:
# Manufacturer
# Porsche         12.128
# Infiniti        23.713
# BMW             26.758
# Audi            40.557
# Lexus           43.145
# Oldsmobile      60.180
# Plymouth        62.129
# Lincoln         62.709
# Acura           64.891
# Mercedes-B      66.079
# Cadillac        81.450
# Saturn         110.389
# Chrysler       117.545
# Hyundai        137.326
# Volkswagen     159.749
# Mitsubishi     180.895
# Mercury        237.999
# Buick          242.019
# Nissan         280.472
# Jeep           293.153
# Pontiac        330.962
# Chevrolet      446.370
# Honda          592.674
# Toyota         675.086
# Dodge          720.798
# Ford          1846.965
# Name: Sales_in_thousands, dtype: float64

# %%
car=pd.read_csv("car_done.csv")
car.isnull().sum()
# Out:
# Unnamed: 0                 0
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb_weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# Latest_Launch              0
# Power_perf_factor          2
# dtype: int64

# %%
car["four_year_resale_value"].fillna(2,inplace=True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_28388\3455776054.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car["four_year_resale_value"].fillna(2,inplace=True)

# %%
car.isnull().sum()
# Out:
# Unnamed: 0                0
# Manufacturer              0
# Model                     0
# Sales_in_thousands        0
# four_year_resale_value    0
# Vehicle_type              0
# Price_in_thousands        2
# Engine_size               1
# Horsepower                1
# Wheelbase                 1
# Width                     1
# Length                    1
# Curb_weight               2
# Fuel_capacity             1
# Fuel_efficiency           3
# Latest_Launch             0
# Power_perf_factor         2
# dtype: int64

# %%
car.describe()
# Out:
#        Unnamed: 0  Sales_in_thousands  four_year_resale_value  \
# count  157.000000          157.000000              157.000000
# mean    78.000000           52.998076               14.387452
# std     45.466105           68.029422               12.118358
# min      0.000000            0.110000                2.000000
# 25%     39.000000           14.114000                7.750000
# 50%     78.000000           29.450000               13.025000
# 75%    117.000000           67.956000               18.140000
# max    156.000000          540.561000               67.550000
#
#        Price_in_thousands  Engine_size  Horsepower   Wheelbase       Width  \
# count          155.000000   156.000000  156.000000  156.000000  156.000000
# mean            27.390755     3.060897  185.948718  107.487179   71.150000
# std             14.351653     1.044653   56.700321    7.641303    3.451872
# min              9.235000     1.000000   55.000000   92.600000   62.600000
# ...

# %%
car["four_year_resale_value"].describe()
# Out:
# count    157.000000
# mean      14.387452
# std       12.118358
# min        2.000000
# 25%        7.750000
# 50%       13.025000
# 75%       18.140000
# max       67.550000
# Name: four_year_resale_value, dtype: float64

# %%
car["four_year_resale_value"].median()
# Out:
# np.float64(13.025)

# %%
car["four_year_resale_value"].fillna(car["four_year_resale_value"].median(),inplace=True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_28388\2390722695.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car["four_year_resale_value"].fillna(car["four_year_resale_value"].median(),inplace=True)

# %%
import matplotlib.pyplot as plt
plt.boxplot(car["four_year_resale_value"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x236bdf19a50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x236bdea1bd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x236bdea0590>],
#  'medians': [<matplotlib.lines.Line2D at 0x236bdf2ca90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x236bdf2d650>],
#  'means': []}
