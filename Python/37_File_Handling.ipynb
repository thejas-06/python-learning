# %%
file =open("37_file.txt","r")
contents=file.read()
print(contents)
file.close()
# Out:
# Hi! i am thejas

# %%
file =open("37_file.txt","r")
contents=file.readlines()
print(contents)
file.close()
# Out:
# ['Hi! i am thejas\n', 'This is file handling concept']

# %%
file =open("37_file.txt","r")
contents=file.readline()
print(contents)
file.close()
# Out:
# Hi! i am thejas

# %%
file =open("37_file_write.txt","w")
file.write("Thejas\n")
file.write("teju")
file.close()

# %%
file =open("37_file_write.txt","a")  # 'a' is append, if we use 'w' it overwrites
file.write("\nTezz")
file.close()

# %%
file =open("37_file_write.txt","r")
contents=file.readlines()
print(contents)
file.close()
# Out:
# ['Thejas\n', 'teju\n', 'Tezz']

# %%
file = None
try:
    file =open("37_file_write.txt","x") # 'x' create new file
    file.write("Thejas")
except Exception as e:
    print(f"Error: e")
finally:
    if file:
        file.close()
# Out:
# Error: e

# %%
s=["Thejas","Tejas","Tezz"]
file=open("37_me.txt","w")
for student in s:
    file.write(f"{student}\n")
file.close()

# %%
# Recommended way
s=["Thejas","Tejas","Tezz"]
with open("37_mee.txt","w") as file:
    for student in s:
        file.write(f"{student}\n")
