# %%
a=int(input("A: "))
b=int(input("B: "))
try:
    print(a/b)
except:
    print("Error")
finally:
    print("is it resolve or not")
# Out:
# 4.25
# is it resolve or not

# %%
a=int(input("A: "))
b=int(input("B: "))
try:
    print(a/b)
except Exception as e:
    print(f"Error {e}")
finally:
    print("is it resolve or not")
# Out:
# Error division by zero
# is it resolve or not

# %%
a=int(input("A: "))
b=int(input("B: "))
try:
    print(a/b)
except Exception as e:
    print(f"Error {e}")
    b=int(input("enter correct B: "))
    print(a/b)
finally:
    print("is it resolve or not")
# Out:
# Error division by zero
# 1.6666666666666667
# is it resolve or not

# %%
a=int(input("A: "))
b=int(input("B: "))
try:
    print(a/b)
except Exception as e:
    print(f"Error {e}")
else:
    print("No error")
# Out:
# 9.666666666666666
# No error

# %%
try:
    a=int(input("A: "))
    b=int(input("B: "))
    print(a/b)
except ZeroDivisionError:
    print("Can't divide by zero")
except ValueError:
    print("please enter a valid number")
# Out:
# please enter a valid number

# %%
try:
    a=int(input("A: "))
    b=int(input("B: "))
    if b==0:
        raise Exception("b can't be zero")
    print(a/b)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: b can't be zero
