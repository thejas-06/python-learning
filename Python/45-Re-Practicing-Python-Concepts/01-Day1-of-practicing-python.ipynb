# %%
a=[21,22,"teju",[10,20,"tejas"]]
a[3][2]
# Out:
# 'tejas'

# %%
a={1,2,3}
b={1,4,5}

print(a | b)
# Out:
# {1, 2, 3, 4, 5}

# %%
numbers = [1, 2, 3, 4]
result = list(map(lambda x: x ** 2, numbers))
print(result)
# Out:
# [1, 4, 9, 16]

# %%
x=2
a=lambda x:"even" if x%2==0 else "odd"
print(a(x))
# Out:
# even

# %%
x=0
b=lambda x:1 if x==0 else x*(x-1)
print(b(0))
# Out:
# 1

# %%
x=[25,22,25,34]
c=list(map(lambda x:(x*9/5)+32,x))
print(c)
# Out:
# [77.0, 71.6, 77.0, 93.2]

# %%
x=["thejas","teju","tezz"]
c=list(filter(lambda x:len(x)>4,x))
print(c)
# Out:
# ['thejas']

# %%
from functools import reduce
z=[1,2,3,4,5]
c=reduce(lambda x,y:x*y,z)
print(c)
# Out:
# 120
